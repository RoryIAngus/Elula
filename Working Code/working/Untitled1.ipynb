# %%
plotValue = ['tip_amount', 'total_amount']
byValue = ['vendor_id', 'payment_type', 'Taxi Use', 'tripLength', 'tripDuration',  'pickup_dayName', \
           'pickup_weekdayWeekend', 'pickup_timeOfDay']
plotValue = ['tip_amount', 'total_amount']
byValue = ['vendor_id', 'payment_type', 'Taxi Use', 'tripLength', 'tripDuration',  'pickup_dayName', \
           'pickup_weekdayWeekend', 'pickup_timeOfDay']
​
​
dfSlice = tripDataFare[['tip_amount', 'total_amount', 'pickup_weekdayWeekend']]
dfSlice = dfSlice.groupby('pickup_weekdayWeekend')
len(tripDataFare['Taxi Use'].unique())
len(tripDataFare['Taxi Use'].unique())
5
plotValue = ['tip_amount', 'total_amount']
byValue = ['vendor_id', 'payment_type', 'Taxi Use', 'tripLength', 'tripDuration',  'pickup_dayName', \
           'pickup_weekdayWeekend', 'pickup_timeOfDay']
​
​
for pv in plotValue:
    for bv in byValue:
        dfSlice = tripDataFare[[pv, bv]]
        dfSlice = dfSlice.groupby(bv)
        # to make sure the plots have the same height i need to calc the plot hieght based on the number of values in variable
        print(math.ceil((len(dfSlice[bv].unique())) *2.5))
        plotHeight = math.ceil((len(dfSlice[bv].unique())) *2.5)
        ax = dfSlice.boxplot(
        # sym='k.',  # symbol used to plot outliers
        subplots=True,
        figsize=(15, plotHeight),
        showfliers=False,
        grid=False,
        rot=0)
​
        plt.show()
​
5

13

13

15

15

18

5

15

5

13

13

15

15

18

5

15

​
    ax = dfSlice.boxplot(
    # sym='k.',  # symbol used to plot outliers
    subplots=True,
    figsize=(15, numberplots *2.5),
    showfliers=True,
    grid=False,
    rot=90)
​
    plt.show()
dfSlice = tripDataFare[['tip_amount', 'total_amount', 'pickup_weekdayWeekend']]
dfSlice = dfSlice.groupby('pickup_weekdayWeekend')
​
​
ax = dfSlice.boxplot(
    # sym='k.',  # symbol used to plot outliers
    subplots=True,
    figsize=(15, 5),
    showfliers=False,
    grid=False,
    rot=90)
​
plt.show()
​
ax = dfSlice.boxplot(
    # sym='k.',  # symbol used to plot outliers
    subplots=True,
    figsize=(15, 5),
    showfliers=True,
    grid=False,
    rot=90)
​
plt.show()
color=dict(boxes='r', whiskers='r', medians='b', caps='r'),
    boxprops=dict(linestyle='-', linewidth=1.5),
    flierprops=dict(linestyle='-', linewidth=1.5),
    medianprops=dict(linestyle='-', linewidth=1.5),
    whiskerprops=dict(linestyle='-', linewidth=1.5),
    capprops=dict(linestyle='-', linewidth=1.5),
ax = dfSlice.plot(
    kind='box',
    # sym='k.',  # symbol used to plot outliers
    subplots=False,
    figsize=(10, 5),
    color=dict(boxes='r', whiskers='r', medians='b', caps='r'),
    boxprops=dict(linestyle='-', linewidth=1.5),
    flierprops=dict(linestyle='-', linewidth=1.5),
    medianprops=dict(linestyle='-', linewidth=1.5),
    whiskerprops=dict(linestyle='-', linewidth=1.5),
    capprops=dict(linestyle='-', linewidth=1.5),
    showfliers=False,
    grid=False,
    rot=90)
# ax.set_xlabel('Diagnose Survey (1st)')
# ax.set_ylabel('Bar in X')
​
plt.show()
​
​


​
